# %% [markdown]
# <font size=6><center>**Machine Learning Pipeline**</center><font>
# <font size=4><center>*An Implementation of Financial Distress Prediction*</center><font>
# <font size=3><center>*Yeol Ye <br> University of Chicago<br>ziyuye@uchicago.edu*</center><font>

# %%
import 1-data-preparation
# Out:
#   File "<ipython-input-23-c402a19e61ef>", line 1
#     import 1-data-preparation
#            ^
# SyntaxError: invalid syntax

# %%
data_file = 'credit-data.csv'
df_file = 'df.pkl'
dict_file='Data Dictionary.xls'

# %%
data_transforming(data_file, df_file, dict_file='Data Dictionary.xls')

# %%
df = data_loading(df_file)

# %%
df
# Out:
#        PersonID  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0         98976                 0                              1.000000   55
# 1         98991                 0                              0.547745   71
# 2         99012                 0                              0.044280   51
# 3         99023                 0                              0.914249   55
# 4         99027                 0                              0.026599   45
# 5         99033                 0                              0.142231   57
# 6         99044                 0                              0.047601   48
# 7         99048                 0                              0.022141   34
# 8         99056                 0                              0.241805   30
# 9         99058                 0                              0.036181   71
# 10        99062                 0                              0.000000   50
# ...
